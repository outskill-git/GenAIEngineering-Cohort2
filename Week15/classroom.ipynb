# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
# Method 1: Using random.uniform()
def generate_ages_random(n, min_age=0, max_age=100):
    """Generate n random ages using random.uniform()"""
    ages = [random.uniform(min_age, max_age) for _ in range(n)]
    return ages

ages1 = generate_ages_random(100, 18, 60)
print(ages1)
plt.figure(figsize=(10, 6))
plt.bar(ages1, range(len(ages1)))
plt.xlabel('Age')
plt.ylabel('Index')
plt.title('Age Bar Chart')
plt.show()
# Out:
# [48.770391052969345, 30.02529839743595, 27.7715751684958, 42.33447380518089, 21.181087015466403, 54.33100193969411, 27.417351494198904, 20.277349481961405, 51.85965517616462, 21.434567195624812, 42.15843971823493, 25.91140610690568, 21.92629745263686, 58.02465146013905, 18.299729786629836, 52.09230013199509, 19.290913000475857, 31.86152386481139, 41.68613457834233, 53.70540723385595, 42.92143103820529, 43.40230545408251, 39.84457770875818, 40.45599631423173, 33.149469034720816, 51.44313377197669, 27.8696570740221, 22.872662443994358, 23.732616866136134, 45.988203752469204, 24.759434241834573, 57.841229804784234, 36.08967880898298, 56.09356031749255, 19.169339539889606, 39.60344358367472, 46.544322898199695, 34.04337999253897, 40.07081720475507, 45.925441554464584, 47.0989279240905, 39.05793800402465, 27.5442088837556, 21.855238991993197, 55.02135493284338, 30.81472037641933, 44.76911727806909, 33.14017352190818, 36.25704016233312, 33.016962132242575, 39.03827719005149, 48.92343534083929, 18.64576232107786, 45.48630751898122, 23.870085933209694, 46.18687270245448, 32.25611235718077, 22.0664163073955, 31.182806075162407, 33.07990945293209, 36.47776165810346, 55.138163751553954, 44.370539002200964, 19.852577963813623, 34.33342646259389, 55.44938860839882, 21.155063950417496, 18.70245992521656, 28.205909319109953, 27.54060504262137, 37.221065968573114, 35.110709988508574, 41.91275334606706, 43.34446222068395, 53.99774684282404, 55.097000172211196, 49.880991040486734, 49.64030059336456, 40.35668881360172, 27.565475226277204, 41.74542701767534, 30.51663606355585, 59.77975941420716, 18.0176792681928, 57.061801518856655, 48.69710533366823, 48.550775564795984, 46.60631841288382, 51.45550469117057, 44.726364471412, 49.988467270594526, 19.42079825845987, 53.8992522904649, 32.10559650093547, 42.865520621033426, 57.716657364598795, 36.20106104755426, 50.46287184647781, 41.873345683789424, 54.59409843907268]

# %%
# Method 2: Using numpy.random.uniform()
def generate_ages_numpy(n, min_age=0, max_age=100):
    """Generate n random ages using numpy"""
    ages = np.random.uniform(min_age, max_age, size=n)
    return ages
ages2 = generate_ages_numpy(10, 18, 65)
print(ages2)
plt.figure(figsize=(10, 6))
plt.bar(range(len(ages2)), ages2)
plt.xlabel('Index')
plt.ylabel('Age')
plt.title('Age Bar Chart')
plt.show()
# Out:
# [49.18001021 61.60220035 41.3958545  20.38118615 38.01949861 58.01986484
#  61.98399866 61.82714644 26.87933236 37.50989659]

# %%
# Method 3: For integer ages only
def generate_integer_ages(n, min_age=0, max_age=100):
    """Generate n random integer ages"""
    ages = [random.randint(min_age, max_age) for _ in range(n)]
    return ages
ages3 = generate_integer_ages(10, 18, 65)
print(ages3)

plt.figure(figsize=(10, 6))
plt.bar(range(len(ages3)), ages3)
plt.xlabel('Index')
plt.ylabel('Age')
plt.title('Age Bar Chart')
plt.show()
# Out:
# [22, 18, 24, 44, 59, 40, 22, 29, 63, 27]

# %%
# For realistic adult ages
adult_ages = np.random.uniform(18, 80, size=20)
print("Adult ages:", [round(age) for age in adult_ages])

plt.figure(figsize=(10, 6))
plt.bar(range(len(adult_ages)), adult_ages)
plt.xlabel('Index')
plt.ylabel('Age')
plt.title('Age Bar Chart')
plt.show()
# Out:
# Adult ages: [69, 34, 57, 49, 56, 49, 40, 34, 70, 25, 33, 65, 75, 50, 19, 25, 61, 25, 51, 51]

# %%
from scipy import stats
# Create a visual comparison of discrete vs continuous distributions
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
fig.suptitle('Discrete vs Continuous Distributions', fontsize=16, fontweight='bold')

# Discrete Distribution Example: Binomial
n, p = 10, 0.3
x_discrete = np.arange(0, n+1)
y_discrete = stats.binom.pmf(x_discrete, n, p)

print(np.round(y_discrete, 3))  # Round for better readability

axes[0].bar(x_discrete, y_discrete, alpha=0.7, color='steelblue', edgecolor='black')
axes[0].set_title('Discrete Distribution\n(Binomial: n=10, p=0.3)', fontweight='bold')
axes[0].set_xlabel('Number of Successes (k)')
axes[0].set_ylabel('Probability P(X = k)')
axes[0].grid(True, alpha=0.3)
axes[0].set_xticks(x_discrete)
# Out:
# [0.028 0.121 0.233 0.267 0.2   0.103 0.037 0.009 0.001 0.    0.   ]
# [<matplotlib.axis.XTick at 0x14c8de210>,
#  <matplotlib.axis.XTick at 0x14c8ddad0>,
#  <matplotlib.axis.XTick at 0x14c93abd0>,
#  <matplotlib.axis.XTick at 0x14c944f90>,
#  <matplotlib.axis.XTick at 0x14c9469d0>,
#  <matplotlib.axis.XTick at 0x14c94cd50>,
#  <matplotlib.axis.XTick at 0x14c94f210>,
#  <matplotlib.axis.XTick at 0x14c951590>,
#  <matplotlib.axis.XTick at 0x14c9539d0>,
#  <matplotlib.axis.XTick at 0x14c958450>,
#  <matplotlib.axis.XTick at 0x14c95a8d0>]
